# %%
import json
from glob import glob
result_paths = glob("overtake/*.json")
print(len(result_paths))
# Out:
# 83

# %%
for result_path in result_paths:
    with open(result_path, "r") as f:
        result = json.load(f)
    # print(result['task_result'])
    if result["task_result"]:
        print(result_path)
# Out:
# overtake/training_tfexample.tfrecord-00000-of-01000.scenario_265.log.json
# overtake/training_tfexample.tfrecord-00000-of-01000.scenario_245.log.json
# overtake/training_tfexample.tfrecord-00000-of-01000.scenario_206.log.json
# overtake/training_tfexample.tfrecord-00000-of-01000.scenario_164.log.json
# overtake/training_tfexample.tfrecord-00000-of-01000.scenario_059.log.json
